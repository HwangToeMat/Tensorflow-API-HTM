# %%
import os

os.chdir('/content/drive/My Drive/api_master/models/research/object_detection/faster_rcnn_resnet101_kitti_2018_01_28/result')

# %%
# !python create_carplate_tf_record.py  --data_dir '/content/drive/My Drive/api_master/models/research/object_detection/carplate_data' --output_dir '/content/drive/My Drive/api_master/models/research/object_detection/data'
# Out:
# WARNING:tensorflow:From create_carplate_tf_record.py:248: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/api_master/models/research/object_detection/utils/label_map_util.py:138: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0220 06:34:14.598699 139922709784448 module_wrapper.py:139] From /content/drive/My Drive/api_master/models/research/object_detection/utils/label_map_util.py:138: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# I0220 06:34:14.600491 139922709784448 create_carplate_tf_record.py:211] Reading from carplate dataset.
# I0220 06:34:14.603195 139922709784448 create_carplate_tf_record.py:226] 155 training and 67 validation examples.
# ...

# %%
  # !pip install tensorboardcolab

# %%
from tensorboardcolab import TensorBoardColab, TensorBoardColabCallback

tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# http://1663962e.ngrok.io

# %%
os.environ['PYTHONPATH']=os.environ['PYTHONPATH']+':/content/drive/My Drive/api_master/models/research/slim'

# %%
# !python '/content/drive/My Drive/api_master/models/research/model_main.py'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
# INFO:tensorflow:Finished evaluation at 2020-02-21-22:10:55
# I0221 22:10:55.752758 139881038894976 evaluation.py:275] Finished evaluation at 2020-02-21-22:10:55
# ...
